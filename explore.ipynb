# %%
import os
import json
data_path = os.path.join('data/', "abcd_v1.1.json")
raw_data = json.load(open(data_path, 'r'))

# %%
for dic in raw_data['train'][0]['delexed']:
    print(dic)
# Out:
# {'speaker': 'agent', 'text': 'hi!', 'turn_count': 1, 'targets': ['return_size', 'retrieve_utterance', None, [], 87], 'candidates': [27949, 7582, 13567, 17765, 36101, 3654, 19384, 24610, 11279, 18856, 21389, 5960, 28378, 28236, 9549, 28427, 3660, 18433, 17370, 32708, 20048, 22386, 32336, 35202, 2178, 23898, 10637, 38498, 28360, 9512, 8556, 22822, 10788, 428, 8235, 21382, 25976, 14142, 32709, 22689, 21264, 26272, 5067, 9121, 9927, 3400, 16443, 20966, 7033, 3207, 1080, 5564, 35240, 37169, 5142, 34655, 6283, 7709, 31778, 39529, 31187, 33287, 12122, 15235, 27885, 29649, 22412, 29223, 28004, 5810, 8593, 30743, 4894, 39776, 17575, 9911, 27374, 33801, 11525, 31743, 11878, 29584, 33171, 10248, 30543, 17682, 36400, 3112, 20065, 3202, 37277, 31274, 21881, 24298, 3919, 12550, 12941, 39672, 7837, 17887]}
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

d1 = np.array([4, 18, 16, 127, 19, 97, 213, 122, 40, 13, 21, 21, 18, 152, 505, 114, 5, 775, 797, 343], dtype=np.float64)
d2 = np.array([2, 24, 23, 91, 10, 78, 71, 107, 31, 10, 13, 27, 22, 90, 422, 42, 3, 548, 602, 348], dtype=np.float64)
d3 = np.array([6, 48, 13, 133, 22, 79, 105, 142, 33, 21, 12, 44, 11, 95, 370, 110, 9, 623, 668, 332], dtype=np.float64)
d4 = np.array([11, 18, 16, 216, 33, 121, 180, 257, 24, 53, 23, 94, 18, 177, 586, 135, 34, 796, 902, 358], dtype=np.float64)
d5 = np.array([3, 24, 5, 83, 11, 74, 190, 32, 47, 8, 13, 4, 13, 52, 421, 74, 1, 621, 664, 392], dtype=np.float64)
d1 /= np.sum(d1)
d2 /= np.sum(d2)
d3 /= np.sum(d3)
d4 /= np.sum(d4)
d5 /= np.sum(d5)
ind = np.arange(20)
plt.figure(figsize=(30,10))
width = 0.1     
plt.bar(ind, d1, width, label='domain1')
plt.bar(ind + width, d2, width, label='domain2')
plt.bar(ind + width*2, d3, width, label='domain3')
plt.bar(ind + width*3, d4, width, label='domain4')
plt.bar(ind + width*4, d5, width, label='domain5')
plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

d1 = np.array([1, 1, 1, 1, 1, 1, 358, 1, 741, 3, 1, 744, 1, 15, 1, 1, 1, 627, 511, 1], dtype=np.float64)
d2 = np.array([1, 1, 1, 1, 1, 1, 304, 1, 632, 9, 1, 614, 1, 39, 1, 1, 1, 569, 384, 1], dtype=np.float64)
d3 = np.array([1, 1, 1, 1, 1, 1, 343, 1, 640, 7, 1, 643, 1, 27, 1, 1, 1, 542, 385, 1], dtype=np.float64)
d4 = np.array([1, 1, 5, 1, 1, 2, 348, 1, 546, 18, 1, 553, 1, 9, 1, 2, 1, 421, 334, 1], dtype=np.float64)
d5 = np.array([1, 1, 1, 1, 1, 1, 306, 1, 663, 4, 1, 659, 1, 6, 1, 1, 1, 570, 447, 1], dtype=np.float64)
d1 /= np.sum(d1)
d2 /= np.sum(d2)
d3 /= np.sum(d3)
d4 /= np.sum(d4)
d5 /= np.sum(d5)
ind = np.arange(20)
plt.figure(figsize=(30,10))
width = 0.1     
plt.bar(ind, d1, width, label='domain1')
plt.bar(ind + width, d2, width, label='domain2')
plt.bar(ind + width*2, d3, width, label='domain3')
plt.bar(ind + width*3, d4, width, label='domain4')
plt.bar(ind + width*4, d5, width, label='domain5')
plt.legend(loc='best')
plt.show()
